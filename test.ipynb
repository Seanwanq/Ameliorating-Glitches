# %%
import pandas as pd
import numpy as np

data_a = np.load("data/dataset_all_V1_bootstrap_O3a.npy")
pd.DataFrame(data_a)
# Out:
#                0          1           2          3         4         5    6
# 0       9.517451   7.082010  152.196493  30.715828 -0.144738  0.104227  4.0
# 1      23.934838  11.774585   67.339999   7.718377 -0.861250 -0.467627  1.0
# 2       8.322346   5.146934   93.468914  17.888047 -0.203238 -0.012615  4.0
# 3       9.122890  11.532085  325.987187  45.616315  0.129675  0.135129  3.0
# 4      11.770522   6.543893   59.974914   6.295871 -0.770255 -0.284936  1.0
# ...          ...        ...         ...        ...       ...       ...  ...
# 23395  32.777141  67.196725   94.838890  18.988526 -0.512530  0.243126  2.0
# 23396   4.828626   1.082018   48.494657   6.284949  0.944889  0.201483  0.0
# 23397   8.938753   5.027900  102.654303  14.774279 -0.092678  0.240242  4.0
# 23398   7.178475   4.487157  505.575632  60.047493  0.064439  0.118413  3.0
# 23399   4.124433   0.774523   66.365741   9.649902  0.949962  0.516277  3.0
#
# [23400 rows x 7 columns]
